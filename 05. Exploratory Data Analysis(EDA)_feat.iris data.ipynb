# %%
import pandas as pd
# %matplotlib inline
from sklearn.datasets import load_iris

iris = load_iris()
iris_df = pd.DataFrame(iris.data, columns=iris.feature_names)
groups = list(iris.target)
iris_df['groups'] = pd.Series([iris.target_names[k] for k in groups])
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#         groups
# 0       setosa
# ...

# %%
boxplots = iris_df.boxplot(return_type='axes')

# %%
boxplots = iris_df.boxplot(column='sepal length (cm)', by='groups', return_type='axes')

# %%
ax = iris_df[iris_df.groups=='setosa'].plot.scatter(x='sepal length (cm)', y='sepal width (cm)', 
                                                    color='red', label='setosa')
iris_df[iris_df.groups=='versicolor'].plot.scatter(x='sepal length (cm)', y='sepal width (cm)', 
                                                color='green', label='versicolor', ax=ax)
iris_df[iris_df.groups=='virginica'].plot.scatter(x='sepal length (cm)', y='sepal width (cm)', 
                                                color='blue', label='virginica', ax=ax)
ax.set_title("scatter")
# Out:
# Text(0.5, 1.0, 'scatter')

# %% [markdown]
# # Multivariate Normal

# %% [markdown]
# The multivariate normal, multinormal or Gaussian distribution is a generalization of the one-dimensional normal distribution to higher dimensions. Such a distribution is specified by its mean and covariance matrix. These parameters are analogous to the mean (average or “center”) and variance (standard deviation, or “width,” squared) of the one-dimensional normal distribution.

# %%
mean = [0, 0]
cov = [[1, 0], [0, 1]]  # diagonal covariance

# %%
import matplotlib.pyplot as plt
import numpy as np
x, y = np.random.multivariate_normal(mean, cov, 5000).T
plt.plot(x, y, 'x')
plt.axis('equal')
plt.show()

# %% [markdown]
# Let's try some other means

# %%
mean = [1,1]
cov =  [[1, 0], [0, 1]] 
x, y = np.random.multivariate_normal(mean, cov, 5000).T
plt.plot(x, y, 'x')
plt.axis('equal')
plt.show()

# %%
mean = [-3,10]
cov =  [[1, 0], [0, 1]] 
x, y = np.random.multivariate_normal(mean, cov, 5000).T
plt.plot(x, y, 'x')
plt.axis('equal')
plt.show()

# %% [markdown]
# Let's try some other cov

# %%
mean = [1,1]
cov =  [[4, 0], [0, 1]] 
plt.plot(x, y, 'x')
x, y = np.random.multivariate_normal(mean, cov, 5000).T
plt.axis('equal')
plt.show()

# %%
from numpy import linalg as LA
w, v = LA.eig(cov)

# %%
w
# Out:
# array([4., 1.])

# %%
v
# Out:
# array([[1., 0.],
#        [0., 1.]])

# %%
mean = [1,1]
cov =  [[2, 1], [1, 2]] 
x, y = np.random.multivariate_normal(mean, cov, 5000).T
plt.plot(x, y, 'x')
plt.axis('equal')
plt.show()

# %%
from numpy import linalg as LA
w, v = LA.eig(cov)
print(w)
print(v)
# Out:
# [3. 1.]
# [[ 0.70710678 -0.70710678]
#  [ 0.70710678  0.70710678]]

# %%
mean = [0,0]
cov =  [[3, 2], [2, 3]] 
x, y = np.random.multivariate_normal(mean, cov, 5000).T
plt.plot(x, y, 'x')
plt.axis('equal')
plt.show()

# %%
mean = [0,0]
cov =  [[3, -2], [-2, 3]] 
x, y = np.random.multivariate_normal(mean, cov, 5000).T
plt.plot(x, y, 'x')
plt.axis('equal')
plt.show()

# %% [markdown]
# # Finding mean and covariance ?

# %%
np.cov([x,y])
# Out:
# array([[ 3.09221842, -2.1218059 ],
#        [-2.1218059 ,  3.11844236]])

# %%
np.mean(x)
# Out:
# -0.009032948180437256

# %%
np.mean(y)
# Out:
# 0.018914386982076422

# %%
mean = np.mean([x,y], axis=1)
mean
# Out:
# array([-0.00903295,  0.01891439])

# %% [markdown]
# what is axis?
#
# computation direction
# 0 : column
# 1 : row
